# %%
import numpy as np
import argparse

import matplotlib.pyplot as plt

# %%
import pickle

# %%
with open("result/lda-n.pkl",'rb') as file:
    object_file = pickle.load(file)
    
results_train = object_file['results_train']
results_valid = object_file['results_valid']
results_title = object_file['results_title']

results_train = np.array(results_train).T
results_train_metric = np.nanmedian(results_train, axis=0)
results_valid = [valid[~np.isnan(valid)] for valid in results_valid]
results_valid = np.array(results_valid).T

plt.cla()
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111)

# ax_r = plt.twinx()
_ = ax.boxplot(results_valid)
_ = ax.plot(np.arange(1, len(results_train_metric) + 1), results_train_metric, 'o-', label=f'trainset: ll')
ax.set_xticks(range(1, len(results_train_metric) + 1))
ax.set_xticklabels(results_title)
ax.set_xlabel(f'N & K')
ax.set_ylabel(f'll')
ax.legend()

plt.tight_layout()
plt_path = 'result' + f'/lda-n-ll.jpg'
plt.savefig(plt_path)

# %%
with open("result/lda-nk.pkl",'rb') as file:
    object_file = pickle.load(file)
    
results_train = object_file['results_train']
results_valid = object_file['results_valid']
results_title = object_file['results_title']

results_train = np.array(results_train).T
results_train_metric = np.nanmedian(results_train, axis=0)
results_valid = [valid[~np.isnan(valid)] for valid in results_valid]
results_valid = np.array(results_valid).T

plt.cla()
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111)

# ax_r = plt.twinx()
_ = ax.boxplot(results_valid)
_ = ax.plot(np.arange(1, len(results_train_metric) + 1), results_train_metric, 'o-', label=f'trainset: ll')
ax.set_xticks(range(1, len(results_train_metric) + 1))
ax.set_xticklabels(results_title)
ax.set_xlabel(f'N & K')
ax.set_ylabel(f'll')
ax.legend()

plt.tight_layout()
plt_path = 'result' + f'/lda-nk-ll.jpg'
plt.savefig(plt_path)

# %%
with open("result/lda-k.pkl",'rb') as file:
    object_file = pickle.load(file)
    
results_train = object_file['results_train']
results_valid = object_file['results_valid']
results_title = object_file['results_title']

results_train = np.array(results_train).T
results_train_metric = np.nanmedian(results_train, axis=0)
results_valid = [valid[~np.isnan(valid)] for valid in results_valid]
results_valid = np.array(results_valid).T

plt.cla()
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111)

# ax_r = plt.twinx()
_ = ax.boxplot(results_valid)
_ = ax.plot(np.arange(1, len(results_train_metric) + 1), results_train_metric, 'o-', label=f'trainset: ll')
ax.set_xticks(range(1, len(results_train_metric) + 1))
ax.set_xticklabels(results_title)
ax.set_xlabel(f'N & K')
ax.set_ylabel(f'll')
ax.legend()

plt.tight_layout()
plt_path = 'result' + f'/lda-k-ll.jpg'
plt.savefig(plt_path)

# %%
with open("result/ctm-n.pkl",'rb') as file:
    object_file = pickle.load(file)
    
results_train = object_file['results_train']
results_valid = object_file['results_valid']
results_title = object_file['results_title']

results_train = np.array(results_train).T
results_train_metric = np.nanmedian(results_train, axis=0)
results_valid = [valid[~np.isnan(valid)] for valid in results_valid]
results_valid = np.array(results_valid).T

plt.cla()
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111)

# ax_r = plt.twinx()
_ = ax.boxplot(results_valid)
_ = ax.plot(np.arange(1, len(results_train_metric) + 1), results_train_metric, 'o-', label=f'trainset: ll')
ax.set_xticks(range(1, len(results_train_metric) + 1))
ax.set_xticklabels(results_title)
ax.set_xlabel(f'N & K')
ax.set_ylabel(f'll')
ax.legend()

plt.tight_layout()
plt_path = 'result' + f'/ctm-k-ll-2.jpg'
plt.savefig(plt_path)

# %%
object_file
# Out:
# {'results_train_metric': [-4.684813328364582],
#  'results_train': [array([-3.76517295, -3.19714127, -3.78149995, ..., -3.61582346,
#          -3.23212106, -3.61083272])],
#  'results_valid': [array([-3.4287679 , -3.78377695, -3.14588489, ..., -3.41694343,
#          -2.70806619, -3.32724846])],
#  'results_title': ['3000&20']}
